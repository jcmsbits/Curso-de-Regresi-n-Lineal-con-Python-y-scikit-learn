# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import *

# %%
dataset = pd.read_csv("./housing.csv")

# %%
dataset.tail()
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0

# %%
columns = dataset.columns.to_list()

# %%
data = dataset

# %%
sns.set_theme(style="whitegrid", context="notebook")

# %%
sns.pairplot(dataset, height=2.5)

# %%
cm = np.corrcoef(dataset.values.T)

# %%
cm
# Out:
# array([[ 1.        , -0.61203322, -0.30455931,  0.69720922],
#        [-0.61203322,  1.        ,  0.3604446 , -0.76067006],
#        [-0.30455931,  0.3604446 ,  1.        , -0.5190335 ],
#        [ 0.69720922, -0.76067006, -0.5190335 ,  1.        ]])

# %%
sns.set_theme(font_scale=1.5)

# %%
sns.heatmap(cm, cbar=True, annot=True, yticklabels=columns, xticklabels=columns)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
X = dataset[["RM", "LSTAT"]].values

# %%
Y = dataset["MEDV"].values.reshape(-1,1)

# %%
scX = StandardScaler()
scY = StandardScaler()

# %%
standarX = scX.fit_transform(X)

# %%
standarY = scY.fit_transform(Y)

# %%
slr = LinearRegression()

# %%
slr.fit(standarX,standarY)
# Out:
# LinearRegression()

# %% [markdown]
# Análisis de Resultado

# %%
predict = slr.predict(standarX)

# %%
x_range = np.arange(dataset["RM"].min(), dataset["RM"].max())
y_range = np.arange(dataset["LSTAT"].min(), dataset["LSTAT"].max())

# %%
x_range
# Out:
# array([3.561, 4.561, 5.561, 6.561, 7.561])

# %%
y_range
# Out:
# array([ 1.98,  2.98,  3.98,  4.98,  5.98,  6.98,  7.98,  8.98,  9.98,
#        10.98, 11.98, 12.98, 13.98, 14.98, 15.98, 16.98, 17.98, 18.98,
#        19.98, 20.98, 21.98, 22.98, 23.98, 24.98, 25.98, 26.98, 27.98,
#        28.98, 29.98, 30.98, 31.98, 32.98, 33.98, 34.98, 35.98, 36.98])

# %%
X1, X2 = np.meshgrid(x_range, y_range)

# %%
X1
# Out:
# array([[3.561, 4.561, 5.561, 6.561, 7.561],
#        [3.561, 4.561, 5.561, 6.561, 7.561],
#        [3.561, 4.561, 5.561, 6.561, 7.561],
#        [3.561, 4.561, 5.561, 6.561, 7.561],
#        [3.561, 4.561, 5.561, 6.561, 7.561],
#        [3.561, 4.561, 5.561, 6.561, 7.561],
#        [3.561, 4.561, 5.561, 6.561, 7.561],
#        [3.561, 4.561, 5.561, 6.561, 7.561],
#        [3.561, 4.561, 5.561, 6.561, 7.561],
#        [3.561, 4.561, 5.561, 6.561, 7.561],
#        [3.561, 4.561, 5.561, 6.561, 7.561],
#        [3.561, 4.561, 5.561, 6.561, 7.561],
#        [3.561, 4.561, 5.561, 6.561, 7.561],
#        [3.561, 4.561, 5.561, 6.561, 7.561],
#        [3.561, 4.561, 5.561, 6.561, 7.561],
#        [3.561, 4.561, 5.561, 6.561, 7.561],
#        [3.561, 4.561, 5.561, 6.561, 7.561],
#        [3.561, 4.561, 5.561, 6.561, 7.561],
#        [3.561, 4.561, 5.561, 6.561, 7.561],
#        [3.561, 4.561, 5.561, 6.561, 7.561],
#        [3.561, 4.561, 5.561, 6.561, 7.561],
# ...

# %%
X2
# Out:
# array([[ 1.98,  1.98,  1.98,  1.98,  1.98],
#        [ 2.98,  2.98,  2.98,  2.98,  2.98],
#        [ 3.98,  3.98,  3.98,  3.98,  3.98],
#        [ 4.98,  4.98,  4.98,  4.98,  4.98],
#        [ 5.98,  5.98,  5.98,  5.98,  5.98],
#        [ 6.98,  6.98,  6.98,  6.98,  6.98],
#        [ 7.98,  7.98,  7.98,  7.98,  7.98],
#        [ 8.98,  8.98,  8.98,  8.98,  8.98],
#        [ 9.98,  9.98,  9.98,  9.98,  9.98],
#        [10.98, 10.98, 10.98, 10.98, 10.98],
#        [11.98, 11.98, 11.98, 11.98, 11.98],
#        [12.98, 12.98, 12.98, 12.98, 12.98],
#        [13.98, 13.98, 13.98, 13.98, 13.98],
#        [14.98, 14.98, 14.98, 14.98, 14.98],
#        [15.98, 15.98, 15.98, 15.98, 15.98],
#        [16.98, 16.98, 16.98, 16.98, 16.98],
#        [17.98, 17.98, 17.98, 17.98, 17.98],
#        [18.98, 18.98, 18.98, 18.98, 18.98],
#        [19.98, 19.98, 19.98, 19.98, 19.98],
#        [20.98, 20.98, 20.98, 20.98, 20.98],
#        [21.98, 21.98, 21.98, 21.98, 21.98],
# ...

# %%
plano  = pd.DataFrame({"RM": X1.ravel(), "LSTAT": X2.ravel()})

# %%
plano.head()
# Out:
#       RM  LSTAT
# 0  3.561   1.98
# 1  4.561   1.98
# 2  5.561   1.98
# 3  6.561   1.98
# 4  7.561   1.98

# %%
X1.shape
# Out:
# (36, 5)

# %%
predict = slr.predict(plano.values)

# %%
predict.shape
# Out:
# (180, 1)

# %%
predict = predict.reshape(X1.shape)

# %%
predict.shape
# Out:
# (36, 5)

# %%
predict = scY.inverse_transform(predict)

# %% [markdown]
# fig.gca no funciona. Ahora es fig.add_subplot

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot_surface(X1, X2, predict, alpha = 0.4)
ax.scatter3D(dataset["RM"], dataset["LSTAT"], dataset["MEDV"], color = "r", marker = ".")
ax.view_init(elev=10,azim=5)
